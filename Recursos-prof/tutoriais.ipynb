# %% [markdown]
# ## Python
#
# ### Páginas de Tutoriais e documentações
#
# - [Muitos tutoriais interessantes](https://www.kaggle.com/learn)
# - [Datacamp](https://www.datacamp.com/)
# - [Pandas](https://pandas.pydata.org/docs/index.html)
#
#
# ### Pré-processamento de dados
#
# - Criar e manipular tabelas: [Pandas](https://www.kaggle.com/code/residentmario/creating-reading-and-writing/tutorial)
# - [Limpeza de dados](https://www.kaggle.com/learn/data-cleaning)
# - [O que é um outlier?](https://fernandafperes.com.br/blog/outliers/)
#
# ### Análise Visual de dados
#
# - Biblioteca para vizualização de dados: [Seaborn](https://www.kaggle.com/learn/data-visualization)
# - [Série temporal](https://www.kaggle.com/learn/time-series)
#
# ## Estatística (pura)
#
# - [Matemática computacional](https://gcpeixoto.github.io/FMECD/ipynb/01a-introducao.html)
# - [Análise estatística](https://fernandafperes.com.br/blog/)
# - [Comandos em python](https://pt.python-3.com/?p=3469)
# - [Estatística descritiva e inferencial com python](https://pt.python-3.com/?p=3469)
#
# ### Ferramentas para análise de dados
#
# - https://www.statscalculators.com/#google_vignette
# - https://statsim.com/
# - https://onlinestatscalculator.com/descriptive
# - https://www.statscalculators.com/resources/simulations
#
# ## Banco de dados
#
# ### Cursos de SQL
# - Curso inicial de [SQL](https://www.kaggle.com/learn/intro-to-sql)
# - Curso de [SQL Avançado](https://www.kaggle.com/learn/advanced-sql)
#
#
#
# ## Machine Learning
#
# ### [Feature Engineering](https://www.kaggle.com/code/ryanholbrook/what-is-feature-engineering)
