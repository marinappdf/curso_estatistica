# %% [markdown]
# ## A metáfora da vez: RPG
# Vou tentar (tentar) costurar esse guia com uma grande metáfora de jogo de RPG. Sou jogador de D&D de papel, então vou estar sempre me referindo ao universo da ***Terra Média***, na vibe Senhor dos Anéis, com anões, elfos, guerreiros, paladinos, etc. resolvendo ***missões*** - quests - algumas ***tarefas paralelas*** - side quests - derrotando monstros e salvando princeses, com seu ***equipamentos*** - armaduras, armas - e ***perícias*** - habilidades, poderes.
# Mas, vocês podem adaptar para o que desejarem, como jogos de ação, de tiro, universos paranormais, distópicos, etc.

# %% [markdown]
# ## Organizar o espaço de trabalho (visão geral)
# Ao iniciar um novo projeto voltado para a análise de dados, para o treinamento de máquinas (*machine learning*), e para aplicação de modelos estatísticos de IA, é importante se se preparar para essa missão e equipar sua mochila com os recursos necessárias para o sucesso da missão. Mapear o local de origem e destino dos arquivos/fontes/produtos, identificar o tipo, o formato, dos arquivos que serão manipulados e escolher as ferramentas adequadas para o objetivo do projeto são alguns dos exemplos de ações necessárias para iniciar o trabalho.
#
# É evidente que, ao longo da trajetória, surpresas podem surgir e novas soluções terão que ser aplicadas. Talvez, o que se planejou no início, vai se mostrar insuficiente, exigindo que novas pesquisas sejam realizadas, novas ferramentas sejam mobilizadas. Isso não quer dizer que não é necessário se organizar antes. Pelo contrário, quanto melhor se entender o ponto de partida, suas habilidades e suas armas, mais fácil será identificar quando cada um deles deve ser alterado. O mestre sempre tem uma surpresinha, alguns NPCs podem aparecer e demandar tarefas paralelas, ou tu pode acabar descobrindo que ainda tem que upar muito para derrotar o chefão. Ou, quem sabe, formar a guilda certa.
#
# A seguir, vou listar algumas ações iniciais que podem contribuir para a tarefa. Dependendo do projeto, algumas dessas tarefas serão desnecessárias, enquanto outras, que não estão incluídas a baixo, terão que ser aplicadas.
#
# Se a missão for encontrar um artefato mágico, então os paralelos serão:

# %% [markdown]
# ### Entender o projeto: a missão
# > ***Qual o objetivo deste projeto?***
# > Por que é importante encontrar o artefato?
# > O que irá determinar que o trabalho está pronto e pode ser finalizado?
# > Basta encontrar, ou é preciso quebrar a maldição?
# > Ou, ainda, entregar ele a outra pessoa (uma missão com duas partes?)?
# > Será preciso ***entregar um produto final?***
# > Esse produto é
# 	um relatório de análise de dados?
# 	um modelo de IA?
# 	um conjunto de dados processados?
# 	uma API?
# 	salvar uma aldeia de camponeses inocentes?
# > É um ***projeto de pesquisa?***
# 	Quais são as perguntas de pesquisa?
# 	Devo propor hipóteses, ou apenas verificar as hipóteses propostas por outros?
# 	Eu entendo do assunto da pesquisa?
# 	Eu preciso entender?

# %% [markdown]
# ### Dados brutos/originais: o mapa criptografado que nos leva ao artefato
# > Como você acessa os dados?
# > 	Download, via request http, banco de dados, etc. ?
# > ***Qual o formato dos dados?*** É preciso alterar o formato para poder manipular?
# > O mapa está em um idioma élfico antigo e será necessário buscar alguém que sabe ler?
# > É necessário criar uma cópia deles para manipulação? Onde será registrado?
# > Onde serão registradas os dados após seu processamento/correção?
# > O mapa está dentro de outro artefato mágico então é preciso realizar a missão de abrir o artefato para ter acesso ao mapa?
# > ***Como os dados serão manipulados?***
# > Será necessário instalar ou configurar algum software, ou biblioteca para que se possa manipular os dados?

# %% [markdown]
# ### Ambiente de desenvolvimento: a sala de casa
# > Criar um ***ambiente de desenvolvimento*** python para o projeto.
# > Configurar o ambiente e a IDE adequados para o projeto.
# > Determinar como os scripts, e outros produtos, serão registrados/documentados.
# > Ou seja, vamos jogar na tua casa, ou na minha? Quem vai levar a coca e as trakinas?
#
# ### Documentação e Caderno de Laboratório: ficha do jogador
# > Será necessário versionamento dos códigos?
# > O projeto será desenvolvido de maneira individual ou coletiva?
# > > Vai ser um jogo de mesa, papel, ou online, digital?
# > Como as etapas parciais da pesquisa e desenvolvimento serão registradas?
# > Quais serão as metodologias e softwares ***para registro dee pesquisa e documentação***?
# > Vamos anotar em um papel, ou usar as fichas oficiais?

# %% [markdown]
# Repare que o ***mapa não é o projeto de pesquisa***. Apesar de ambos mostrarem caminhos que podem ser seguidos, o mapa não tem um objetivo, ele carrega a informação e só. Já o projeto, determina o objetivo final, as quests, os recursos, o ambiente, o universo, a equipe, as limitações, etc. É possível pensar nos dados como nossos inimigos, aqueles que queremos derrotar, manipular, dobrar. Mas não me parece bom, porque eles não são os vilões. Também não são poções mágicas que dão poder e nos possibilitam fazer coisas mágicas, isso quem faz são as ferramentas e recursos que usamos. Eles Podem ser transformados em gráficos e modelos estatísticos, mas permanecem **presentes ao longo de todo o projeto**, são o início e o final. O que queremos descobrir (**inferir!**) já está dentro dele desde o início (**licença poética**). Os caminhos do projeto, ferramentas utilizadas e dificuldades apresentadas são moldadas por ele (**e pelas nossas condições materiais de vida né**). Por isso, entendo que os ***dados informam os trajetos possíveis***, enquanto o ***projeto indica a missão que nossos heróis vão enfrentar***.
#
# Disclaimer: cuidado com a noção de que os dados determinam a realidade, que são inquestionáveis, sendo provas da verdade, nada disso!

# %% [markdown]
# ## Visão geral dos Dados
#
# ### Obter os dados: pegar aquele mapa
# (temos que pegar eu sei)
#
# Inicia-se traduzindo o mapa élfico:
# >  transformar os dados em algo que poderá ser manipulado com python.

# %% [markdown]
# #### Vamos facilitar nosso trabalho e baixar um arquivo do tipo `.csv`.
# #### Vamos explorar os dados e depois baixar: [base de dados](https://www.kaggle.com/competitions/store-sales-time-series-forecasting/data).

# %% [markdown]
# ### Ler os dados
# Vamos imaginar que de ***élfico antigo*** consigamos traduzir para um idioma chamado ***python***, no dialeto ***pandas***

# %% [markdown]
# `pip install pandas`

# %%
import pandas as pd

# %% [markdown]
# - [Guia do usuário](https://pandas.pydata.org/docs/user_guide/index.html)
#
# - [Documentação API](https://pandas.pydata.org/docs/reference/)

# %%
df = pd.read_csv("dados\\holidays_events.csv")

# %%
df = pd.read_csv("dados\\holidays_events.csv", sep=',',  na_values=["erro", "$#"])

# %% [markdown]
# - Input/output com pandas: [read_tcharara](https://pandas.pydata.org/docs/reference/io.html)

# %% [markdown]
# ### Conhecer a cara dos dados
#
# É necessário olhar a cara deles. E se vamos colocar em pandas, precisamos que os dados possam ser organizados no formato de ***Dataframes***, ou seja, ***tabelas***.

# %%
df.head()

# %%
df.head(2)

# %%
df.tail(5)

# %%
print(df.size)
print(df.shape)

# %%
df.dtypes

# %%
df.info()

# %% [markdown]
# Verificar o nome das colunas, quem é o index (linhas).

# %%
print(df.columns)

# %%
print(df.index)

# %% [markdown]
# ##### Muitas outras formas de acessar e olhar para esses caras
# -> [Dataframes](https://pandas.pydata.org/docs/reference/frame.html)

# %% [markdown]
# ### Atividade
# ##### Baixo os os dados, disponíveis [aqui](https://www.kaggle.com/competitions/store-sales-time-series-forecasting/data), e responda as seguintes questões (15min):

# %% [markdown]
# > 1. Qual o separador dos dados?

# %% [markdown]
# Vírgula

# %% [markdown]
# > 2. Quantas colunas a base de dados tem?

# %%
df.shape

# %%
df.columns

# %%
len(df.columns)

# %% [markdown]
# > 3. Qual a diferença entre o número de linhas e o index?

# %% [markdown]
# - Linhas e index são equivalentes!
# - Linhas são as linhas da tabela.
# - Cada index é um índice que identificam uma linha.
# - Os index estão listados em uma coluna chamada 'index'.
# - O index é o nome da linha, tal qual columns é o nome das colunas.

# %%
df.shape

# %%
len(df.index)

# %%
list(df.index)

# %%
df.head(10)

# %% [markdown]
# > 4. Qual o tipo de dados de cada coluna? Que problemas você antecipa?

# %%
df.dtypes

# %%
df.head()

# %% [markdown]
# > 5. Por que alguns comandos tem `()` e outros não? Por exemplo, `df.dtypes` e `df.info()`.

# %% [markdown]
# - Com () são métodos, são funções, são ações;
# - Sem () são propriedades, características.
#
# Por exemplo, a carteira de motorista é uma propriedade, mas dirigir é uma ação.

# %%
df.info()

# %%
df.info

# %% [markdown]
# > 6. Qual a diferença entre `print(df.size())` e `df.size`?

# %% [markdown]
# ### ERREI! `df.size()` É UMA PROPRIEDADE, NÃO UM MÉTODO, NÃO TEM '()'!

# %%
df.size()

# %%
df.size

# %% [markdown]
# ##### O que eu queria perguntar é a diferença entre `print(df.size)` e `df.size`

# %%
print(df.size)
df.size

# %%
df.size
print(df.size)

# %%
df.size

# %% [markdown]
# ### Não há diferenças! São equivalentes.
# - `df.size` apenas executa o comando
# - `print(df.size)` executa e imprime
#
# No jupyter, o resultado do último comando de cada célula é impresso, por isso conseguimos ver o resultado apenas digitando `df.size`.

# %% [markdown]
# ## Acessar itens: passo de exploração
# ##### Esse trecho não é um passo necessário, mas acho interessante mostrar como fazer isso.

# %%
df.columns

# %%
df['locale']

# %%
df[ ['locale', 'type']  ]

# %% [markdown]
# #### Filtrar
#
# Acessar valores que satisfazem uma condição.

# %%
df[df["transferred"] != False] # valores que satisfazem a condição, independente de coluna/linha

# %%
df["transferred"] != False

# %%
lista = df["transferred"] != False

# %%
df[lista]
# Out:
#            date     type    locale locale_name                    description  \
# 19   2012-10-09  Holiday  National     Ecuador     Independencia de Guayaquil
# 72   2013-10-09  Holiday  National     Ecuador     Independencia de Guayaquil
# 135  2014-10-09  Holiday  National     Ecuador     Independencia de Guayaquil
# 255  2016-05-24  Holiday  National     Ecuador           Batalla de Pichincha
# 266  2016-07-25  Holiday     Local   Guayaquil         Fundacion de Guayaquil
# 268  2016-08-10  Holiday  National     Ecuador  Primer Grito de Independencia
# 297  2017-01-01  Holiday  National     Ecuador             Primer dia del ano
# 303  2017-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 312  2017-05-24  Holiday  National     Ecuador           Batalla de Pichincha
# 324  2017-08-10  Holiday  National     Ecuador  Primer Grito de Independencia
# 328  2017-09-28  Holiday     Local      Ibarra            Fundacion de Ibarra
# ...

# %%
df[df["transferred"] != False]['type']

# %%
df[ df['locale'] == 'National' ]
# Out:
#            date        type    locale locale_name  \
# 14   2012-08-10     Holiday  National     Ecuador
# 19   2012-10-09     Holiday  National     Ecuador
# 20   2012-10-12    Transfer  National     Ecuador
# 21   2012-11-02     Holiday  National     Ecuador
# 22   2012-11-03     Holiday  National     Ecuador
# ..          ...         ...       ...         ...
# 345  2017-12-22  Additional  National     Ecuador
# 346  2017-12-23  Additional  National     Ecuador
# 347  2017-12-24  Additional  National     Ecuador
# 348  2017-12-25     Holiday  National     Ecuador
# 349  2017-12-26  Additional  National     Ecuador
#
#                              description  transferred
# 14         Primer Grito de Independencia        False
# 19            Independencia de Guayaquil         True
# 20   Traslado Independencia de Guayaquil        False
# 21                       Dia de Difuntos        False
# 22               Independencia de Cuenca        False
# ...

# %% [markdown]
# ##### Filtrar itens que estão em uma lista

# %%
favoritos = ['Imbabura','Latacunga','Machala','Santo Domingo','El Carmen','Cayambe','Esmerald']

# %%
df.isin(favoritos) # condição de pertencimento
# Out:
#       date   type  locale  locale_name  description  transferred
# 0    False  False   False        False        False        False
# 1    False  False   False        False        False        False
# 2    False  False   False        False        False        False
# 3    False  False   False        False        False        False
# 4    False  False   False        False        False        False
# ..     ...    ...     ...          ...          ...          ...
# 345  False  False   False        False        False        False
# 346  False  False   False        False        False        False
# 347  False  False   False        False        False        False
# 348  False  False   False        False        False        False
# 349  False  False   False        False        False        False
#
# [350 rows x 6 columns]

# %%
df['type'].isin(favoritos)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 345    False
# 346    False
# 347    False
# 348    False
# 349    False
# Name: type, Length: 350, dtype: bool

# %%
df.isin(favoritos).sum()
# Out:
# date            0
# type            0
# locale          0
# locale_name    42
# description     0
# transferred     0
# dtype: int64

# %%
df[df['locale_name'].isin(favoritos)]
# Out:
#            date     type    locale    locale_name  \
# 7    2012-06-25  Holiday  Regional       Imbabura
# 8    2012-06-25  Holiday     Local      Latacunga
# 9    2012-06-25  Holiday     Local        Machala
# 10   2012-07-03  Holiday     Local  Santo Domingo
# 11   2012-07-03  Holiday     Local      El Carmen
# 12   2012-07-23  Holiday     Local        Cayambe
# 26   2012-11-11  Holiday     Local      Latacunga
# 58   2013-06-25  Holiday  Regional       Imbabura
# 59   2013-06-25  Holiday     Local        Machala
# 60   2013-06-25  Holiday     Local      Latacunga
# 61   2013-07-03  Holiday     Local      El Carmen
# 62   2013-07-03  Holiday     Local  Santo Domingo
# 63   2013-07-23  Holiday     Local        Cayambe
# 79   2013-11-11  Holiday     Local      Latacunga
# 110  2014-06-25  Holiday     Local      Latacunga
# 111  2014-06-25  Holiday     Local        Machala
# 112  2014-06-25  Holiday  Regional       Imbabura
# 118  2014-07-03  Holiday     Local      El Carmen
# ...

# %%
df[df['locale_name'].isin(favoritos)]['locale_name']
# Out:
# 7           Imbabura
# 8          Latacunga
# 9            Machala
# 10     Santo Domingo
# 11         El Carmen
# 12           Cayambe
# 26         Latacunga
# 58          Imbabura
# 59           Machala
# 60         Latacunga
# 61         El Carmen
# 62     Santo Domingo
# 63           Cayambe
# 79         Latacunga
# 110        Latacunga
# 111          Machala
# 112         Imbabura
# 118        El Carmen
# 119    Santo Domingo
# 126          Cayambe
# 142        Latacunga
# 176          Machala
# 177         Imbabura
# 178        Latacunga
# 179        El Carmen
# 180    Santo Domingo
# 181          Cayambe
# 196        Latacunga
# 258          Machala
# 259         Imbabura
# 260        Latacunga
# 261        El Carmen
# 262    Santo Domingo
# 263          Cayambe
# 281        Latacunga
# 315         Imbabura
# 316        Latacunga
# 317          Machala
# 318        El Carmen
# 319    Santo Domingo
# 320          Cayambe
# 337        Latacunga
# Name: locale_name, dtype: str

# %% [markdown]
# #### Identificar categorias, espectro, intervalo

# %%
df['locale'].unique()
# Out:
# <StringArray>
# ['Local', 'Regional', 'National']
# Length: 3, dtype: str

# %% [markdown]
# #### Acessar itens pela posição
#
# - [Indexing](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-basics-get-value)

# %%
df.iloc[0] # Posição numérica / index / linha
# Out:
# date                   2012-03-02
# type                      Holiday
# locale                      Local
# locale_name                 Manta
# description    Fundacion de Manta
# transferred                 False
# Name: 0, dtype: object

# %%
df.iloc[[0,1]]

# %%
df.loc[[0,1]]# Posição segundo o NOME DO ÍNDICE
# Out:
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
#
#    transferred
# 0        False
# 1        False

# %% [markdown]
# > ##### São o mesmo resultado por que NESTE CASOS dos índex são iguais a sua posição.

# %% [markdown]
# > ####  Hmmm -> Por que está sendo usado `[]` e não `()`?  -.^

# %%
df.iloc[4]
# Out:
# date                          2012-04-21
# type                             Holiday
# locale                             Local
# locale_name                     Riobamba
# description    Cantonizacion de Riobamba
# transferred                        False
# Name: 4, dtype: object

# %%
df.head(5)
# Out:
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
df['type'][0]
# Out:
# 'Holiday'

# %%
df.columns
# Out:
# Index(['date', 'type', 'locale', 'locale_name', 'description', 'transferred'], dtype='str')

# %%
df.columns[2]
# Out:
# 'locale'

# %%
df['date']
# Out:
# 0      2012-03-02
# 1      2012-04-01
# 2      2012-04-12
# 3      2012-04-14
# 4      2012-04-21
#           ...
# 345    2017-12-22
# 346    2017-12-23
# 347    2017-12-24
# 348    2017-12-25
# 349    2017-12-26
# Name: date, Length: 350, dtype: str

# %%
df['date'][2]
# Out:
# '2012-04-12'

# %% [markdown]
# #### Series em pandas
#
# ##### Dataframe é um conjunto de colunas.
# ##### Uma coluna sozinha é uma série.

# %%
serie1 = df['type']
print(serie1)
# Out:
# 0         Holiday
# 1         Holiday
# 2         Holiday
# 3         Holiday
# 4         Holiday
#           ...
# 345    Additional
# 346    Additional
# 347    Additional
# 348       Holiday
# 349    Additional
# Name: type, Length: 350, dtype: str

# %% [markdown]
# ##### Alguns métodos de pandas podem ser aplicados apenas a séries, alguns métodos apenas em dataframes.
# - [`Series.str.startswith`](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.startswith.html#pandas.Series.str.startswith "pandas.Series.str.startswith")
# - [`Series.str.endswith`](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.endswith.html#pandas.Series.str.endswith "pandas.Series.str.endswith")
# - [`Series.str.contains`](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.contains.html#pandas.Series.str.contains "pandas.Series.str.contains")

# %%
df.eq(serie1, axis='index') # condição de equivalência entre df e series
# Out:
#       date  type  locale  locale_name  description  transferred
# 0    False  True   False        False        False        False
# 1    False  True   False        False        False        False
# 2    False  True   False        False        False        False
# 3    False  True   False        False        False        False
# 4    False  True   False        False        False        False
# ..     ...   ...     ...          ...          ...          ...
# 345  False  True   False        False        False        False
# 346  False  True   False        False        False        False
# 347  False  True   False        False        False        False
# 348  False  True   False        False        False        False
# 349  False  True   False        False        False        False
#
# [350 rows x 6 columns]

# %%
serie2 = df.iloc[3]
print(serie2)
# Out:
# date                          2012-04-14
# type                             Holiday
# locale                             Local
# locale_name                     Libertad
# description    Cantonizacion de Libertad
# transferred                        False
# Name: 3, dtype: object

# %%
df.eq(serie2, axis='columns')
# Out:
#       date   type  locale  locale_name  description  transferred
# 0    False   True    True        False        False         True
# 1    False   True   False        False        False         True
# 2    False   True    True        False        False         True
# 3     True   True    True         True         True         True
# 4    False   True    True        False        False         True
# ..     ...    ...     ...          ...          ...          ...
# 345  False  False   False        False        False         True
# 346  False  False   False        False        False         True
# 347  False  False   False        False        False         True
# 348  False   True   False        False        False         True
# 349  False  False   False        False        False         True
#
# [350 rows x 6 columns]

# %%
df[df.eq(serie2, axis='columns')] # equivalente à df[df.eq(serie2, axis='columns') == True]
# Out:
#            date     type locale locale_name                description  \
# 0           NaN  Holiday  Local         NaN                        NaN
# 1           NaN  Holiday    NaN         NaN                        NaN
# 2           NaN  Holiday  Local         NaN                        NaN
# 3    2012-04-14  Holiday  Local    Libertad  Cantonizacion de Libertad
# 4           NaN  Holiday  Local         NaN                        NaN
# ..          ...      ...    ...         ...                        ...
# 345         NaN      NaN    NaN         NaN                        NaN
# 346         NaN      NaN    NaN         NaN                        NaN
# 347         NaN      NaN    NaN         NaN                        NaN
# 348         NaN  Holiday    NaN         NaN                        NaN
# 349         NaN      NaN    NaN         NaN                        NaN
#
#     transferred
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...

# %% [markdown]
# #### Voltando para o roteiro, vamos iniciar outra etapa:
# ## Limpeza dos dados
#
# Nesta etapa, vamos limpar os dados: corrigir tipos, tratar nulos e faltantes, incorretos, outliers e etc.

# %% [markdown]
# ## Limpeza dos dados: Corrigir tipos

# %%
df.dtypes

# %%
df.head(2)

# %%
date_series = pd.to_datetime(['2012-03-02', '2012-04-01', '2012-04-12', '2012-04-14', '2012-04-2'])
print(date_series)

# %%
df['date'] = pd.to_datetime( df['date'] )
print(df.info())

# %%
exemplo = pd.DataFrame(['1', '3', '5', '8'])
exemplo.dtypes

# %%
exemplo = pd.to_numeric(exemplo[0])
exemplo.dtypes

# %% [markdown]
# - [Mais sobre converter string para datetime.](https://www.datacamp.com/tutorial/converting-strings-datetime-objects)
# - [Para quem quer entender sobre o que são tipos de dados em python e quais são eles.](https://www.datacamp.com/blog/python-data-types)
# - [Lista com tipos de dados.](https://pandas.pydata.org/docs/reference/arrays.html)
# - Converter para numérico: [pd.to_numeric()](https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html#)

# %% [markdown]
# ## Limpeza dos dados: Identificar nulos e faltantes
#
# Valores marcados como NA, None, Vazio, etc. Eles irão prejudicar a análise e precisam ser corrigidos.
#
# As estratégias para resolver esse problema podem ser resumidas em: ***deletar*** ou ***substituir***.
#
# |Ação | Prós| Contras | Algorítimo|
# |---|---|---|---|
# | Deletar todas as linhas com pelo menos 1 valor nulo | Fácil, rápido, não altera o comportamento da amostra| Para bases pequenas, ou para muitos valores nulos, deletar pode prejudicar o tamanho da amostra, e leva a perda de valores não nulos.| Filtrar e deletar: `df.dropna()`|
# | Substituir pela média/moda| Não há perda de dados, não altera o comportamento médio| Altera o comportamento local, pode afetar a análise| Filtrar e substituir pela média/moda da coluna: `df.fillna()` e `df.mean()`. Para dados categóricos, usar o valor mais frequente.|
# | Substituir por uma nova categoria "Não informado", ou 0 | Não há perda de dados | Pode alterar o comportamento médio e local, adiciona mais uma categoria para análise| Filtrar e substituir: `df.fillna()`e `= "Não informado"`|
# |Deletar a coluna: quando há uma coluna com muitos valores nulos, pode ser vantajoso excluir ela da análise| Fácil, não interfere no comportamento geral | Se a variável for relevante para a análise, pode prejudicar o resultado| Deletar: `df.drop()`|

# %% [markdown]
# #### Verificando na nossa base:

# %%
df.isnull()

# %%
df.isnull().sum()

# %%
df.info()

# %% [markdown]
# #### Mas se tivesse nulo, o que poderiamos fazer?

# %% [markdown]
# Vou inserir dados nulos falsos

# %%
df.iloc[1] = [None, None,None,None, None, None]

# %%
print(df.head(3))

# %%
print(df.info())
print(df.isnull().sum())

# %%
df.dropna(axis='index', inplace=True)
# df = df.dropna(axis='index')
print(df.values)

# %% [markdown]
# ##### Observação: clicando na função com ctrl ou botão direito -> ver implementação

# %% [markdown]
# ### Limpeza dos dados: linhas repetidas

# %%
df.duplicated()

# %%
df.duplicated().sum()

# %% [markdown]
# > - Para deletar as duplicatas: [df.drop_duplicates()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html)

# %% [markdown]
# ### Limpeza dos dados: erros de escrita

# %%
df.unique() # vai dar erro

# %%
df.columns

# %%
print(df['type'].unique())
print(df['locale'].unique())
print(df['locale_name'].unique())
print(df['description'].unique())

# %% [markdown]
# ##### Parece que não tem nenhum erro . . .mas e se quiséssemos que tudo estivesse com letra minúscula?

# %%
df['type'].str.lower()

# %% [markdown]
# ##### E para fazer para todos os campos?

# %%
# df.columns
campos_categoricos = ['type', 'locale', 'locale_name', 'description']
for campo in campos_categoricos:
    print(campo)
    df[campo] = df[campo].str.lower()
    print(df[campo].unique())
    print('')

# %% [markdown]
# #### Caso queira corrigir palavras ou alterar nomes:

# %%
df.replace('holiday', 'férias', inplace=True)
print(df['type'].unique())

# %% [markdown]
# ### Limpeza de dados: Outliers
#
# Outliers são dados que fogem a norma. Dados que são tão diferentes que podem prejudicar a análise.
# Vamos entender eles mais tarde, depois de aprendermos a fazer análise visual e estatística descritiva.

# %% [markdown]
# ## Atividade
#
# ### Tratamento dos dados\atividade_02.ipynb

# %% [markdown]
# ### Atividades Extras
# 1. Substitua todas as palavras em inglês no campo 'type' por suas traduções para o português. Use um loop para agilizr a substituição
#
# ```
# ingles = ['holiday', 'transfer', 'additional', 'bridge', 'work day', 'event']`
# traducao = ['férias', 'transferência', 'adicional', 'ponte', 'dia útil', 'evento']
# ```
#
# 2. Substitua todos os valores booleanos do campo 'transfered' for 0 e 1, para `False` e `True`, respectivamente.

# %% [markdown]
# # Próximos passos: Estatística Descritiva, Análise Visual e Identificação de Outliers

# %% [markdown]
# # Estatística descritiva

# %%
df.describe()
# Out:
#               date     type    locale locale_name description transferred
# count          350      350       350         350         350         350
# unique         312        6         3          24         103           2
# top     2014-06-25  Holiday  National     Ecuador    Carnaval       False
# freq             4      221       174         174          10         338

# %% [markdown]
# Vamos adicionar uma coluna fictícia com preços
